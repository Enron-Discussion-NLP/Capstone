# %%
# Here We'll test wrangle modules / explore modules / anything else needed

# %%
import wrangle
import pandas as pd

import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

import seaborn as sns

# %%
df = wrangle.acquire_emails()

# %%
df.head()
# Out:
#                        file    subject                   sender  \
# 0     allen-p/_sent_mail/1.             phillip.allen@enron.com
# 1    allen-p/_sent_mail/10.        Re:  phillip.allen@enron.com
# 2   allen-p/_sent_mail/100.   Re: test  phillip.allen@enron.com
# 3  allen-p/_sent_mail/1000.             phillip.allen@enron.com
# 4  allen-p/_sent_mail/1001.  Re: Hello  phillip.allen@enron.com
#
#                                     date  \
# 0  Mon, 14 May 2001 16:39:00 -0700 (PDT)
# 1   Fri, 4 May 2001 13:51:00 -0700 (PDT)
# 2  Wed, 18 Oct 2000 03:00:00 -0700 (PDT)
# 3  Mon, 23 Oct 2000 06:13:00 -0700 (PDT)
# 4  Thu, 31 Aug 2000 05:07:00 -0700 (PDT)
#
#                                              content
# 0                          Here is our forecast\n\n
# 1  Traveling to have a business meeting takes the...
# 2                     test successful.  way to go!!!
# 3  Randy,\n\n Can you send me a schedule of the s...
# 4                Let's shoot for Tuesday at 11:45.

# %%
df, time_series_df = wrangle.create_dataframes_wrangle()
# Out:
# polarity and subjectivity algo complete
# added sub and pol to df

# %%
df.head()
# Out:
#                        file    subject                   sender  \
# 0     allen-p/_sent_mail/1.             phillip.allen@enron.com
# 1    allen-p/_sent_mail/10.        Re:  phillip.allen@enron.com
# 2   allen-p/_sent_mail/100.   Re: test  phillip.allen@enron.com
# 3  allen-p/_sent_mail/1000.             phillip.allen@enron.com
# 4  allen-p/_sent_mail/1001.  Re: Hello  phillip.allen@enron.com
#
#                                     date  \
# 0  Mon, 14 May 2001 16:39:00 -0700 (PDT)
# 1   Fri, 4 May 2001 13:51:00 -0700 (PDT)
# 2  Wed, 18 Oct 2000 03:00:00 -0700 (PDT)
# 3  Mon, 23 Oct 2000 06:13:00 -0700 (PDT)
# 4  Thu, 31 Aug 2000 05:07:00 -0700 (PDT)
#
#                                              content  \
# 0                          Here is our forecast\n\n
# 1  Traveling to have a business meeting takes the...
# 2                     test successful.  way to go!!!
# 3  Randy,\n\n Can you send me a schedule of the s...
# 4                Let's shoot for Tuesday at 11:45.
#
#                                                clean  \
# 0                               here is our forecast
# 1  traveling to have a business meeting takes the...
# 2                         test successful  way to go
# 3  randy   can you send me a schedule of the sala...
# 4                    let's shoot for tuesday at 1145
#
#                                             tokenize  \
# 0                               here is our forecast
# 1  traveling to have a business meeting takes the...
# 2                          test successful way to go
# 3  randy can you send me a schedule of the salary...
# 4                  let ' s shoot for tuesday at 1145
#
#                                           stop_words  \
# 0                                           forecast
# 1  traveling business meeting takes fun trip espe...
# 2                             test successful way go
# 3  randy send schedule salary level everyone sche...
# 4                           let ' shoot tuesday 1145
#
#                                            lemmatize  intensity  polarity  \
# 0                                           forecast     0.0000      0.00
# 1  traveling business meeting take fun trip espec...     0.9313      0.15
# 2                             test successful way go     0.5859      0.75
# 3  randy send schedule salary level everyone sche...     0.0000      0.00
# 4                           let ' shoot tuesday 1145    -0.3400      0.00
#
#    subjectivity  is_poi  is_internal
# 0      0.000000   False         True
# 1      0.613333   False         True
# 2      0.950000   False         True
# 3      0.000000   False         True
# 4      0.000000   False         True

# %%
time_series_df.head()
# Out:
#                            intensity  polarity  subjectivity  year  month
# date
# 1999-01-04 10:21:00+00:00     0.2023  0.000000      0.000000  1999      1
# 1999-01-04 10:21:00+00:00     0.2023  0.000000      0.000000  1999      1
# 1999-01-04 12:11:00+00:00     0.3182  0.016667      0.266667  1999      1
# 1999-01-04 12:11:00+00:00     0.3182  0.016667      0.266667  1999      1
# 1999-01-05 06:36:00+00:00     0.9895  0.076871      0.329783  1999      1

# %%
#df.to_csv('01-clean_data.csv')

# %%
#time_series_df.to_csv('02-ts_data.csv')

# %%
df = pd.read_csv('01-clean_data.csv')
df.head()
# Out:
#    Unnamed: 0                      file    subject                   sender  \
# 0           0     allen-p/_sent_mail/1.        NaN  phillip.allen@enron.com
# 1           1    allen-p/_sent_mail/10.        Re:  phillip.allen@enron.com
# 2           2   allen-p/_sent_mail/100.   Re: test  phillip.allen@enron.com
# 3           3  allen-p/_sent_mail/1000.        NaN  phillip.allen@enron.com
# 4           4  allen-p/_sent_mail/1001.  Re: Hello  phillip.allen@enron.com
#
#                                     date  \
# 0  Mon, 14 May 2001 16:39:00 -0700 (PDT)
# 1   Fri, 4 May 2001 13:51:00 -0700 (PDT)
# 2  Wed, 18 Oct 2000 03:00:00 -0700 (PDT)
# 3  Mon, 23 Oct 2000 06:13:00 -0700 (PDT)
# 4  Thu, 31 Aug 2000 05:07:00 -0700 (PDT)
#
#                                              content  \
# 0                          Here is our forecast\n\n
# 1  Traveling to have a business meeting takes the...
# 2                     test successful.  way to go!!!
# 3  Randy,\n\n Can you send me a schedule of the s...
# 4                Let's shoot for Tuesday at 11:45.
#
#                                                clean  \
# 0                               here is our forecast
# 1  traveling to have a business meeting takes the...
# 2                         test successful  way to go
# 3  randy   can you send me a schedule of the sala...
# 4                    let's shoot for tuesday at 1145
#
#                                             tokenize  \
# 0                               here is our forecast
# 1  traveling to have a business meeting takes the...
# 2                          test successful way to go
# 3  randy can you send me a schedule of the salary...
# 4                  let ' s shoot for tuesday at 1145
#
#                                           stop_words  \
# 0                                           forecast
# 1  traveling business meeting takes fun trip espe...
# 2                             test successful way go
# 3  randy send schedule salary level everyone sche...
# 4                           let ' shoot tuesday 1145
#
#                                            lemmatize  intensity  polarity  \
# 0                                           forecast     0.0000      0.00
# 1  traveling business meeting take fun trip espec...     0.9313      0.15
# 2                             test successful way go     0.5859      0.75
# 3  randy send schedule salary level everyone sche...     0.0000      0.00
# 4                           let ' shoot tuesday 1145    -0.3400      0.00
#
#    subjectivity  is_poi  is_internal
# 0      0.000000   False         True
# 1      0.613333   False         True
# 2      0.950000   False         True
# 3      0.000000   False         True
# 4      0.000000   False         True

# %%
df = df.drop(columns = ['Unnamed: 0'])
df.head()
# Out:
#                        file    subject                   sender  \
# 0     allen-p/_sent_mail/1.        NaN  phillip.allen@enron.com
# 1    allen-p/_sent_mail/10.        Re:  phillip.allen@enron.com
# 2   allen-p/_sent_mail/100.   Re: test  phillip.allen@enron.com
# 3  allen-p/_sent_mail/1000.        NaN  phillip.allen@enron.com
# 4  allen-p/_sent_mail/1001.  Re: Hello  phillip.allen@enron.com
#
#                                     date  \
# 0  Mon, 14 May 2001 16:39:00 -0700 (PDT)
# 1   Fri, 4 May 2001 13:51:00 -0700 (PDT)
# 2  Wed, 18 Oct 2000 03:00:00 -0700 (PDT)
# 3  Mon, 23 Oct 2000 06:13:00 -0700 (PDT)
# 4  Thu, 31 Aug 2000 05:07:00 -0700 (PDT)
#
#                                              content  \
# 0                          Here is our forecast\n\n
# 1  Traveling to have a business meeting takes the...
# 2                     test successful.  way to go!!!
# 3  Randy,\n\n Can you send me a schedule of the s...
# 4                Let's shoot for Tuesday at 11:45.
#
#                                                clean  \
# 0                               here is our forecast
# 1  traveling to have a business meeting takes the...
# 2                         test successful  way to go
# 3  randy   can you send me a schedule of the sala...
# 4                    let's shoot for tuesday at 1145
#
#                                             tokenize  \
# 0                               here is our forecast
# 1  traveling to have a business meeting takes the...
# 2                          test successful way to go
# 3  randy can you send me a schedule of the salary...
# 4                  let ' s shoot for tuesday at 1145
#
#                                           stop_words  \
# 0                                           forecast
# 1  traveling business meeting takes fun trip espe...
# 2                             test successful way go
# 3  randy send schedule salary level everyone sche...
# 4                           let ' shoot tuesday 1145
#
#                                            lemmatize  intensity  polarity  \
# 0                                           forecast     0.0000      0.00
# 1  traveling business meeting take fun trip espec...     0.9313      0.15
# 2                             test successful way go     0.5859      0.75
# 3  randy send schedule salary level everyone sche...     0.0000      0.00
# 4                           let ' shoot tuesday 1145    -0.3400      0.00
#
#    subjectivity  is_poi  is_internal
# 0      0.000000   False         True
# 1      0.613333   False         True
# 2      0.950000   False         True
# 3      0.000000   False         True
# 4      0.000000   False         True

# %%
df.date = pd.to_datetime(df.date, utc=True)

# %%
isPoi_df = df[df.is_poi == True]
isPoi_df.head()
# Out:
#                                  file                                subject  \
# 1042        allen-p/all_documents/50.               New Generation, Nov 30th
# 1284       allen-p/deleted_items/149.                       Check this out -
# 1694  allen-p/discussion_threads/190.               New Generation, Nov 30th
# 2103          allen-p/notes_inbox/40.               New Generation, Nov 30th
# 8641      badeer-r/all_documents/101.  RE: Path 26 OTC increase -- IMPORTANT
#
#                       sender                      date  \
# 1042    tim.belden@enron.com 2000-12-05 06:42:00+00:00
# 1284  jeff.richter@enron.com 2001-10-23 14:44:39+00:00
# 1694    tim.belden@enron.com 2000-12-05 06:42:00+00:00
# 2103    tim.belden@enron.com 2000-12-05 06:42:00+00:00
# 8641    tim.belden@enron.com 2000-08-20 21:12:00+00:00
#
#                                                 content  \
# 1042  ---------------------- Forwarded by Tim Belden...
# 1284  Phillip,\n\nWhich one should I do, the 8x12 is...
# 1694  ---------------------- Forwarded by Tim Belden...
# 2103  ---------------------- Forwarded by Tim Belden...
# 8641  check this out and let everyone know what's up...
#
#                                                   clean  \
# 1042   forwarded by tim beldenhouect on 12052000 054...
# 1284  phillip  which one should i do the 8x12 is hal...
# 1694   forwarded by tim beldenhouect on 12052000 054...
# 2103   forwarded by tim beldenhouect on 12052000 054...
# 8641  check this out and let everyone know what's up...
#
#                                                tokenize  \
# 1042  forwarded by tim beldenhouect on 12052000 0544...
# 1284  phillip which one should i do the 8x12 is half...
# 1694  forwarded by tim beldenhouect on 12052000 0544...
# 2103  forwarded by tim beldenhouect on 12052000 0544...
# 8641  check this out and let everyone know what ' s ...
#
#                                              stop_words  \
# 1042  forwarded tim beldenhouect 12052000 0544 krist...
# 1284  phillip one 8x12 half price jeff original mess...
# 1694  forwarded tim beldenhouect 12052000 0544 krist...
# 2103  forwarded tim beldenhouect 12052000 0544 krist...
# 8641  check let everyone know ' forwarded tim belden...
#
#                                               lemmatize  intensity  polarity  \
# 1042  forwarded tim beldenhouect 12052000 0544 krist...     0.0000 -0.015152
# 1284  phillip one 8x12 half price jeff original mess...     0.9831  0.065981
# 1694  forwarded tim beldenhouect 12052000 0544 krist...     0.0000 -0.015152
# 2103  forwarded tim beldenhouect 12052000 0544 krist...     0.0000 -0.015152
# 8641  check let everyone know ' forwarded tim belden...     0.9756  0.013605
#
#       subjectivity  is_poi  is_internal
# 1042      0.393939    True         True
# 1284      0.428776    True         True
# 1694      0.393939    True         True
# 2103      0.393939    True         True
# 8641      0.358503    True         True

# %%
isPoi_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5579 entries, 1042 to 516364
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   file          5579 non-null   object
#  1   subject       5358 non-null   object
#  2   sender        5579 non-null   object
#  3   date          5579 non-null   datetime64[ns, UTC]
#  4   content       5579 non-null   object
#  5   clean         5576 non-null   object
#  6   tokenize      5576 non-null   object
#  7   stop_words    5573 non-null   object
#  8   lemmatize     5573 non-null   object
#  9   intensity     5579 non-null   float64
#  10  polarity      5579 non-null   float64
#  11  subjectivity  5579 non-null   float64
#  12  is_poi        5579 non-null   bool
#  13  is_internal   5579 non-null   bool
# dtypes: bool(2), datetime64[ns, UTC](1), float64(3), object(8)
# memory usage: 577.5+ KB

# %%
df_2000, df_2001 = wrangle.create_topic_dataframes(df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [5], in <module>
# ----> 1 df_2000, df_2001 = wrangle.create_topic_dataframes(df)
#
# File ~\Desktop\test\Capstone\wrangle.py:394, in create_topic_dataframes(df)
#     391 def create_topic_dataframes(df):
#     392     is_poi_df = df[df.is_poi == True]
# --> 394     df_2000 = is_poi_df[is_poi_df.date.year == 2000]
#     395     df_2001 = is_poi_df[is_poi_df.date.year == 2001]
#     397     return df_2000, df_2001
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:5583, in NDFrame.__getattr__(self, name)
#    5576 if (
#    5577     name not in self._internal_names_set
#    5578     and name not in self._metadata
#    5579     and name not in self._accessors
#    5580     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5581 ):
#    5582     return self[name]
# -> 5583 return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'year'

# %%
df.head()
# Out:
#                        file    subject                   sender  \
# 0     allen-p/_sent_mail/1.        NaN  phillip.allen@enron.com
# 1    allen-p/_sent_mail/10.        Re:  phillip.allen@enron.com
# 2   allen-p/_sent_mail/100.   Re: test  phillip.allen@enron.com
# 3  allen-p/_sent_mail/1000.        NaN  phillip.allen@enron.com
# 4  allen-p/_sent_mail/1001.  Re: Hello  phillip.allen@enron.com
#
#                        date  \
# 0 2001-05-14 23:39:00+00:00
# 1 2001-05-04 20:51:00+00:00
# 2 2000-10-18 10:00:00+00:00
# 3 2000-10-23 13:13:00+00:00
# 4 2000-08-31 12:07:00+00:00
#
#                                              content  \
# 0                          Here is our forecast\n\n
# 1  Traveling to have a business meeting takes the...
# 2                     test successful.  way to go!!!
# 3  Randy,\n\n Can you send me a schedule of the s...
# 4                Let's shoot for Tuesday at 11:45.
#
#                                                clean  \
# 0                               here is our forecast
# 1  traveling to have a business meeting takes the...
# 2                         test successful  way to go
# 3  randy   can you send me a schedule of the sala...
# 4                    let's shoot for tuesday at 1145
#
#                                             tokenize  \
# 0                               here is our forecast
# 1  traveling to have a business meeting takes the...
# 2                          test successful way to go
# 3  randy can you send me a schedule of the salary...
# 4                  let ' s shoot for tuesday at 1145
#
#                                           stop_words  \
# 0                                           forecast
# 1  traveling business meeting takes fun trip espe...
# 2                             test successful way go
# 3  randy send schedule salary level everyone sche...
# 4                           let ' shoot tuesday 1145
#
#                                            lemmatize  intensity  polarity  \
# 0                                           forecast     0.0000      0.00
# 1  traveling business meeting take fun trip espec...     0.9313      0.15
# 2                             test successful way go     0.5859      0.75
# 3  randy send schedule salary level everyone sche...     0.0000      0.00
# 4                           let ' shoot tuesday 1145    -0.3400      0.00
#
#    subjectivity  is_poi  is_internal
# 0      0.000000   False         True
# 1      0.613333   False         True
# 2      0.950000   False         True
# 3      0.000000   False         True
# 4      0.000000   False         True

# %%
def create_time_series_df_allyears(df):
    df = df.drop(columns = ['file', 'sender', 'subject', 'content', 'clean', 'tokenize', 'stop_words', 'lemmatize', 'is_internal', 'is_poi'])

    df.date = pd.to_datetime(df.date, utc=True)

    df = df.set_index('date').sort_index()

    df['year'] = df.index.year
    df['month'] = df.index.month
    
    return df

# %%
df = create_time_series_df_allyears(df)
df.head()
# Out:
#                            intensity  polarity  subjectivity  year  month
# date
# 1980-01-01 00:00:00+00:00     0.6124 -0.104861      0.431250  1980      1
# 1980-01-01 00:00:00+00:00     0.0000  0.000000      0.000000  1980      1
# 1980-01-01 00:00:00+00:00     0.9943  0.278879      0.575575  1980      1
# 1980-01-01 00:00:00+00:00     0.6908  0.008333      0.633333  1980      1
# 1980-01-01 00:00:00+00:00     0.7184  0.043810      0.373810  1980      1

# %%
df.index.year.value_counts()
# Out:
# 2001    272964
# 2000    196100
# 2002     35974
# 1999     11144
# 1980       522
# 1997       437
# 1998       177
# 2004        70
# 2044         3
# 1986         2
# 2012         2
# 2020         2
# 2005         1
# 2007         1
# 2024         1
# 2043         1
# Name: date, dtype: int64

# %%
#df.to_csv('03-ts_all_years_data.csv')

# %%
df.head()
# Out:
#                            intensity  polarity  subjectivity  year  month
# date
# 1980-01-01 00:00:00+00:00     0.6124 -0.104861      0.431250  1980      1
# 1980-01-01 00:00:00+00:00     0.0000  0.000000      0.000000  1980      1
# 1980-01-01 00:00:00+00:00     0.9943  0.278879      0.575575  1980      1
# 1980-01-01 00:00:00+00:00     0.6908  0.008333      0.633333  1980      1
# 1980-01-01 00:00:00+00:00     0.7184  0.043810      0.373810  1980      1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 517401 entries, 1980-01-01 00:00:00+00:00 to 2044-01-04 22:48:58+00:00
# Data columns (total 5 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   intensity     517401 non-null  float64
#  1   polarity      517401 non-null  float64
#  2   subjectivity  517401 non-null  float64
#  3   year          517401 non-null  int64
#  4   month         517401 non-null  int64
# dtypes: float64(3), int64(2)
# memory usage: 23.7 MB

# %%
#using train data
by_date = df.groupby(['date']).intensity.sum().reset_index()
by_date.head()
# Out:
#                        date  intensity
# 0 1980-01-01 00:00:00+00:00   248.8645
# 1 1986-04-26 15:22:07+00:00     0.9628
# 2 1986-05-01 14:37:34+00:00     0.8617
# 3 1997-01-01 17:22:03+00:00     0.5267
# 4 1997-03-03 11:00:00+00:00     0.0000

# %%
coolguy = df.groupby(['date']).polarity.sum().reset_index()
doglover = df.groupby(['date']).subjectivity.sum().reset_index()

# %%
#using train data
#plt.figure(figsize=(16,10))
by_date.plot(x = 'date', y = 'intensity', figsize=(16,10))
# Out:
# <AxesSubplot:xlabel='date'>

# %%
coolguy.plot(x = 'date', y = 'polarity', figsize=(16,10))
# Out:
# <AxesSubplot:xlabel='date'>

# %%
doglover.plot(x = 'date', y = 'subjectivity', figsize=(16,10))
# Out:
# <AxesSubplot:xlabel='date'>
